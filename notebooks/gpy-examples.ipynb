# %%
import GPy.examples.regression as r
# %matplotlib inline

# %%
r.olympic_marathon_men()
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 6.947137912152781<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# ...

# %%
r.coregionalization_toy()
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: gp<br>
# <b>Objective</b>: -82.5046835229551<br>
# <b>Number of Parameters</b>: 8<br>
# <b>Number of Optimization Parameters</b>: 8<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# ...

# %%
r.coregionalization_sparse()
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: sparse gp<br>
# <b>Objective</b>: -89.72870543711906<br>
# <b>Number of Parameters</b>: 48<br>
# <b>Number of Optimization Parameters</b>: 28<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# ...

# %%
r.epomeo_gpx()
# Out:
# Acquiring resource: epomeo_gpx
#
# Details of data:
# Five different GPS traces of the same run up Mount Epomeo in Ischia. The traces are from different sources. endomondo_1 and endomondo_2 are traces from the mobile phone app Endomondo, with a split in the middle. garmin_watch_via_endomondo is the trace from a Garmin watch, with a segment missing about 4 kilometers in. viewranger_phone and viewranger_tablet are traces from a phone and a tablet through the viewranger app. The viewranger_phone data comes from the same mobile phone as the Endomondo data (i.e. there are 3 GPS devices, but one device recorded two traces).
#
# After downloading the data will take up 2031872 bytes of space.
#
# Data will be stored in /Users/tomdr/ods_data_cache/epomeo_gpx.
#
# Do you wish to proceed with the download? [yes/no]
# yes
# ...
# [==============================]   0.071/0.071MB
# ...
# [==============================]   0.078/0.078MB
# ...
# [==============================]   0.606/0.606MB
# ...

# %%
r.multiple_optima()
# Out:
# Acquiring resource: della_gatta
#
# Details of data:
# The full gene expression data set from della Gatta et al (http://www.ncbi.nlm.nih.gov/pmc/articles/PMC2413161/) processed by RMA.
#
# Please cite:
# Direct targets of the TRP63 transcription factor revealed by a combination of gene expression profiling and reverse engineering. Giusy Della Gatta, Mukesh Bansal, Alberto Ambesi-Impiombato, Dario Antonini, Caterina Missero, and Diego di Bernardo, Genome Research 2008
#
# After downloading the data will take up 3729650 bytes of space.
#
# Data will be stored in /Users/tomdr/ods_data_cache/della_gatta.
#
# Do you wish to proceed with the download? [yes/no]
# yes
# ...
# [==============================]   3.557/3.557MB
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 0.30403764664271726<br>
# ...

# %%
r.olympic_100m_men()
# Out:
# Acquiring resource: rogers_girolami_data
#
# Details of data:
# Data from the textbook 'A First Course in Machine Learning'. Available from http://www.dcs.gla.ac.uk/~srogers/firstcourseml/.
#
# Please cite:
# A First Course in Machine Learning. Simon Rogers and Mark Girolami: Chapman & Hall/CRC, ISBN-13: 978-1439824146
#
# After downloading the data will take up 21949154 bytes of space.
#
# Data will be stored in /Users/tomdr/ods_data_cache/rogers_girolami_data.
#
# Do you wish to proceed with the download? [yes/no]
# yes
# ...
# [==============================]  10.177/10.177MB
# Extracting file.
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 6.463043157164847<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# ...

# %%
r.toy_rbf_1d()
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -387.6984691651572<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# ...

# %%
r.toy_rbf_1d_50()
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -22.62643286775878<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# ...

# %%
r.toy_poisson_rbf_1d_laplace()
# Out:
#  /Users/tomdr/VirtualEnvs/gpml/lib/python3.5/site-packages/GPy/examples/regression.py:280: RuntimeWarning:covariance is not positive-semidefinite.
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: gp<br>
# <b>Objective</b>: 194.19176753243212<br>
# <b>Number of Parameters</b>: 2<br>
# <b>Number of Optimization Parameters</b>: 2<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# ...

# %%
r.toy_ARD()
# Out:
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# ...

# %%
r.toy_ARD_sparse()
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: sparse_gp<br>
# <b>Objective</b>: 1049.3247130800246<br>
# <b>Number of Parameters</b>: 45<br>
# <b>Number of Optimization Parameters</b>: 45<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# ...

# %%
r.silhouette()
# Out:
# Acquiring resource: ankur_pose_data
#
# Details of data:
# Artificially generated data of silhouettes given poses. Note that the data does not display a left/right ambiguity because across the entire data set one of the arms sticks out more the the other, disambiguating the pose as to which way the individual is facing.
#
# Please cite:
# 3D Human Pose from Silhouettes by Relevance Vector Regression (In CVPR'04). A. Agarwal and B. Triggs.
#
# After downloading the data will take up 2802667 bytes of space.
#
# Data will be stored in /Users/tomdr/ods_data_cache/ankur_pose_data.
#
# Do you wish to proceed with the download? [yes/no]
# yes
# ...
# [==============================]   2.673/2.673MB
#
# Name : GP regression
# Objective : 116157.61832914423
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |            value  |  constraints  |  priors
#   rbf.variance             |    139.921808814  |      +ve      |
# ...

# %%
r.sparse_GP_regression_1D()
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: sparse_gp<br>
# <b>Objective</b>: -595.8333406492748<br>
# <b>Number of Parameters</b>: 8<br>
# <b>Number of Optimization Parameters</b>: 8<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# ...

# %%
r.sparse_GP_regression_2D()
# Out:
# Name : sparse_gp
# Objective : -530.7631609239761
# Number of Parameters : 103
# Number of Optimization Parameters : 103
# Updates : True
# Parameters:
#   sparse_gp.               |             value  |  constraints  |  priors
#   inducing_inputs          |           (50, 2)  |               |
#   rbf.variance             |    0.969094283206  |      +ve      |
#   rbf.lengthscale          |     1.87607806603  |      +ve      |
#   Gaussian_noise.variance  |  0.00253179259117  |      +ve      |
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: sparse_gp<br>
# <b>Objective</b>: -530.7631609239761<br>
# <b>Number of Parameters</b>: 103<br>
# <b>Number of Optimization Parameters</b>: 103<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# ...

# %%
r.uncertain_inputs_sparse_regression()
# Out:
# Name : sparse_gp
# Objective : -18.073293308647408
# Number of Parameters : 10
# Number of Optimization Parameters : 10
# Updates : True
# Parameters:
#   sparse_gp.               |             value  |  constraints  |  priors
#   inducing_inputs          |            (7, 1)  |               |
#   rbf.variance             |    0.545987957424  |      +ve      |
#   rbf.lengthscale          |     1.38389182114  |      +ve      |
#   Gaussian_noise.variance  |  0.00142191985491  |      +ve      |
#
# Name : sparse_gp
# Objective : 16.487361565787054
# Number of Parameters : 10
# Number of Optimization Parameters : 10
# Updates : True
# Parameters:
#   sparse_gp.               |           value  |  constraints  |  priors
#   inducing_inputs          |          (7, 1)  |               |
#   rbf.variance             |  0.340186149435  |      +ve      |
#   rbf.lengthscale          |   2.32637825205  |      +ve      |
#   Gaussian_noise.variance  |  0.210993267174  |      +ve      |
# ...

# %%
r.simple_mean_function()
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: gp<br>
# <b>Objective</b>: -13.479621077559269<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# ...

# %%
r.parametric_mean_function()
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: gp<br>
# <b>Objective</b>: -3.305467323744036<br>
# <b>Number of Parameters</b>: 4<br>
# <b>Number of Optimization Parameters</b>: 4<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# ...
